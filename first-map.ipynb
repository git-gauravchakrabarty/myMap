# %%
# Work with vector data
import geopandas as gpd

# Save maps and plots to files
import holoviews as hv
# Create interactive maps and plots
import hvplot.pandas

# Search for locations by name - this might take a moment
from osmnx import features as osm

# %%
# Search for United Tribes Technical College
haskell_gdf = osm.features_from_address(
    'Haskell Indian Nations University, Lawrence, KS, United States',
    {'amenity': ['university']})
haskell_gdf
# Out:
#                                                                    ways  \
# element_type osmid
# relation     2330930  [172603550, 174576051, 174576058, 171002778, 1...
#
#                      addr:city addr:housenumber addr:postcode    addr:street  \
# element_type osmid
# relation     2330930  Lawrence             2300         66046  Barker Avenue
#
#                          amenity        boundary  ele gnis:feature_id  \
# element_type osmid
# relation     2330930  university  protected_area  268          479134
#
#                      heritage  ... nrhp:criteria nrhp:inscription_date  \
# element_type osmid             ...
# relation     2330930        2  ...           (A)          July 4, 1961
#
#                      nrhp:nhl protection_title  ref:nrhp          type  \
# element_type osmid
# relation     2330930      yes   protected_site  66000342  multipolygon
#
#                      wikidata                             wikipedia  \
# element_type osmid
# relation     2330930  Q845332  en:Haskell Indian Nations University
#
#                                                                   nodes  \
# element_type osmid
# relation     2330930  [[[391518501, 1834666320, 1834666332, 12070968...
#
#                                                                geometry
# element_type osmid
# relation     2330930  POLYGON ((-95.23831 38.93552, -95.23817 38.935...
#
# [1 rows x 22 columns]

# %%
haskell_gdf.plot()
# Out:
# <Axes: >

# %%
# Plot haskell boundary
haskell_map = haskell_gdf.reset_index().hvplot(
    # Givethe map a descriptive title
    title="Haskell Indian Nations Universty, Lawrence, KS",
    # Add a basemap
    geo=True, tiles='EsriImagery',
    # Change the colors
    fill_color='white', fill_alpha=0.2,
    line_color='skyblue', line_width=5,
    # Change the image size
    frame_width=1200, frame_height=1200)

# Save the map as a file to put on the web
hv.save(haskell_map, 'haskell.html')

# Display the map
haskell_map
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1393', ...)
# :Overlay
#    .WMTS.I     :WMTS   [Longitude,Latitude]
#    .Polygons.I :Polygons   [Longitude,Latitude]

# %%
# Search VBU Technical College
VBU_gdf = osm.features_from_address(
    'Vinoba Bhave University, Hazaribagh, Jharkhand, India',
    {'amenity': ['university']},dist=500)
VBU_gdf
# Out:
#                                                                     nodes  \
# element_type osmid
# way          524846511  [5106871912, 5106871913, 5106871914, 510687191...
#
#                          addr:city     amenity                     name  \
# element_type osmid
# way          524846511  Hazaribagh  university  Vinoba Bhave University
#
#                        name:etymology:wikidata  wikidata  \
# element_type osmid
# way          524846511                  Q13021  Q7932713
#
#                                          wikipedia  \
# element_type osmid
# way          524846511  en:Vinoba Bhave University
#
#                                                                  geometry
# element_type osmid
# way          524846511  POLYGON ((85.37735 24.02239, 85.37665 24.02274...

# %%
VBU_gdf.plot()
# Out:
# <Axes: >

# %%
VBU_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_128e37a5836abc2e4abd312b8d42f351 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_128e37a5836abc2e4abd312b8d42f351&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_128e37a5836abc2e4abd312b8d42f351 = L.map(
#                 &quot;map_128e37a5836abc2e4abd312b8d42f351&quot;,
#                 {
#                     center: [24.02174075, 85.3730253],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_128e37a5836abc2e4abd312b8d42f351);
#
#
#
#
#
#             var tile_layer_defe185531215ff46c5c467e474eddd9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_defe185531215ff46c5c467e474eddd9.addTo(map_128e37a5836abc2e4abd312b8d42f351);
#
#
#             map_128e37a5836abc2e4abd312b8d42f351.fitBounds(
#                 [[24.0188132, 85.3686959], [24.0246683, 85.3773547]],
#                 {}
#             );
#
#
#         function geo_json_0fd436a9d8a9d27693a7512bee539447_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0fd436a9d8a9d27693a7512bee539447_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0fd436a9d8a9d27693a7512bee539447_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0fd436a9d8a9d27693a7512bee539447_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0fd436a9d8a9d27693a7512bee539447_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_0fd436a9d8a9d27693a7512bee539447.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0fd436a9d8a9d27693a7512bee539447_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0fd436a9d8a9d27693a7512bee539447 = L.geoJson(null, {
#                 onEachFeature: geo_json_0fd436a9d8a9d27693a7512bee539447_onEachFeature,
#
#                 style: geo_json_0fd436a9d8a9d27693a7512bee539447_styler,
#                 pointToLayer: geo_json_0fd436a9d8a9d27693a7512bee539447_pointToLayer,
#         });
#
#         function geo_json_0fd436a9d8a9d27693a7512bee539447_add (data) {
#             geo_json_0fd436a9d8a9d27693a7512bee539447
#                 .addData(data);
#         }
#             geo_json_0fd436a9d8a9d27693a7512bee539447_add({&quot;bbox&quot;: [85.3686959, 24.0188132, 85.3773547, 24.0246683], &quot;features&quot;: [{&quot;bbox&quot;: [85.3686959, 24.0188132, 85.3773547, 24.0246683], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[85.3773547, 24.0223905], [85.3766542, 24.0227403], [85.3765328, 24.0230389], [85.3689674, 24.0246683], [85.3686959, 24.0212024], [85.3697237, 24.0210248], [85.369581, 24.020049], [85.3694039, 24.0190795], [85.3702301, 24.0189413], [85.3712257, 24.0188132], [85.3716015, 24.019161], [85.3720312, 24.0193137], [85.372305, 24.0202126], [85.3737964, 24.0211544], [85.3745945, 24.0219039], [85.3763362, 24.0214438], [85.3768589, 24.0211954], [85.3773547, 24.0223905]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;(\u0027way\u0027, 524846511)&quot;, &quot;properties&quot;: {&quot;ad

# %%
# Plot VBU boundary
VBU_map = VBU_gdf.reset_index().hvplot(
    # Givethe map a descriptive title
    title="Vinoba Bhave Universty, Hazaribagh, India",
    # Add a basemap
    geo=True, tiles='EsriImagery',
    # Change the colors
    fill_color='white', fill_alpha=0.2,
    line_color='skyblue', line_width=5,
    # Change the image size
    frame_width=1200, frame_height=1200)

# Save the map as a file to put on the web
hv.save(VBU_map, 'VBU.html')

# Display the map
VBU_map
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1568', ...)
# :Overlay
#    .WMTS.I     :WMTS   [Longitude,Latitude]
#    .Polygons.I :Polygons   [Longitude,Latitude]

# %%
# %%capture
# %%bash
#Coverting to HTML
jupyter nbconvert first-map.ipynb --to html
